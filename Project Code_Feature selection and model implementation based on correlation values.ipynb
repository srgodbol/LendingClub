# %% [markdown]
# #### Loading the packages and creating spark and sparkcontext objectsa

# %%
from pyspark.sql import SparkSession
import numpy as np

spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

import pyspark
from pyspark.ml import feature, regression, Pipeline, evaluation
from pyspark.ml.classification import LogisticRegression
from pyspark.sql import functions as fn, Row
from pyspark import sql


from pyspark.ml.stat import Correlation 
from pyspark.ml.feature import VectorAssembler

import matplotlib.pyplot as plt
import pandas as pd

from pyspark.ml.stat import Correlation
from sklearn.preprocessing import Imputer

from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml import Pipeline

# %% [markdown]
# #### Loading the dataset

# %%
#df = spark.createDataFrame(pd.read_csv('new_data.csv', low_memory = False))
df = spark.read.format("csv").option("header", "true").option("inferSchema","true").load("data_master.csv")

# %% [markdown]
# #### Excluding extra column added during spark dataframe creation

# %%
df = df.drop(fn.col('_c0')).drop(fn.col('Unnamed: 0'))

# %% [markdown]
# #### Converting loan_status values to 0s & 1s

# %%
df= df.withColumn('loan_status', fn.when(fn.col('loan_status') == 'Default',0).otherwise(1))

# %% [markdown]
# #### Dropping features with Null value count greater than 100000

# %%
df = df.drop(fn.col('mths_since_last_delinq')).\
drop(fn.col('mths_since_last_record')).\
drop(fn.col('mths_since_last_major_derog')).\
drop(fn.col('mths_since_recent_bc_dlq')).\
drop(fn.col('mths_since_recent_revol_delinq')).\
drop(fn.col('deferral_term')).\
drop(fn.col('hardship_amount')).\
drop(fn.col('hardship_length')).\
drop(fn.col('hardship_dpd')).\
drop(fn.col('orig_projected_additional_accrued_interest')).\
drop(fn.col('hardship_payoff_balance_amount')).\
drop(fn.col('hardship_last_payment_amount')).\
drop(fn.col('settlement_amount')).\
drop(fn.col('settlement_percentage')).\
drop(fn.col('settlement_term')).\
drop(fn.col('annual_inc_joint')).\
drop(fn.col('next_pymnt_d')).\
drop(fn.col('hardship_type')).\
drop(fn.col('dti_joint')).\
drop(fn.col('verification_status_joint')).\
drop(fn.col('revol_bal_joint')).\
drop(fn.col('sec_app_earliest_cr_line')).\
drop(fn.col('sec_app_inq_last_6mths')).\
drop(fn.col('sec_app_mort_acc')).\
drop(fn.col('sec_app_open_acc')).\
drop(fn.col('sec_app_revol_util')).\
drop(fn.col('sec_app_open_act_il')).\
drop(fn.col('sec_app_num_rev_accts')).\
drop(fn.col('sec_app_chargeoff_within_12_mths')).\
drop(fn.col('sec_app_collections_12_mths_ex_med')).\
drop(fn.col('sec_app_mths_since_last_major_derog')).\
drop(fn.col('hardship_reason')).\
drop(fn.col('hardship_status')).\
drop(fn.col('hardship_start_date')).\
drop(fn.col('hardship_end_date')).\
drop(fn.col('payment_plan_start_date')).\
drop(fn.col('hardship_loan_status')).\
drop(fn.col('debt_settlement_flag_date')).\
drop(fn.col('settlement_status')).\
drop(fn.col('settlement_date'))

# %%
#Dataset dimension
print((df.count(), len(df.columns)))
# Out:
# (564400, 100)

# %% [markdown]
# #### Dropping na values across the dataset

# %%
df = df.na.drop()

# %%
#Dataset dimension
print((df.count(), len(df.columns)))
# Out:
# (404922, 100)

# %%
df.select('policy_code').distinct().show()
# Out:
# +-----------+
# |policy_code|
# +-----------+
# |          1|
# +-----------+

# %% [markdown]
# #### Dropping the feature policy_code as it has no unique value to contribute to the model

# %%
df = df.drop(fn.col('policy_code'))

# %% [markdown]
# #### Balancing the number of data points in the dataframe based on loan_status value
# #### Here, we are trying to have equal number of data points for loan_status values of 0 and 1

# %%
df_zero = df.where('loan_status = 0')
df_one = df.where('loan_status = 1')

# %%
df_zero.count()
# Out:
# 329912

# %%
df_one.count()
# Out:
# 75010

# %%
df_zero_to_add, df_removed = df_zero.randomSplit([0.24, 0.76], seed=0)
df_new = df_one.union(df_zero_to_add)
df_new.groupBy("loan_status").count().show()
# Out:
# +-----------+-----+
# |loan_status|count|
# +-----------+-----+
# |          1|75010|
# |          0|79400|
# +-----------+-----+

# %%
df = df_new

# %% [markdown]
# #### Selecting columns with the type 'int' and 'double' as numericColumnList and replacing na values with zeros

# %%
numericColumnList = [item[0] for item in df.dtypes if (item[1].startswith('int') | item[1].startswith('double')) ]
df_numeric = df[numericColumnList].na.fill(0) #Impute 0

# %% [markdown]
# #### Number of features wiith type 'int' and 'float'

# %%
len(numericColumnList)
# Out:
# 80

# %% [markdown]
# #### Generating a correlation matrix of data with all the numeric features

# %%
va_corr = feature.VectorAssembler(inputCols = numericColumnList, outputCol = 'features')
features_sample_df = va_corr.transform(df_numeric)
corr = Correlation.corr(features_sample_df,'features').head()
x = corr[0].toArray()
y = pd.DataFrame(x)
y.columns = numericColumnList
y.index = numericColumnList

# %%
y
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv      term  \
# loan_amnt                    1.000000     1.000000         0.999995  0.391881
# funded_amnt                  1.000000     1.000000         0.999995  0.391881
# funded_amnt_inv              0.999995     0.999995         1.000000  0.392185
# term                         0.391881     0.391881         0.392185  1.000000
# int_rate                     0.106926     0.106926         0.107049  0.354823
# installment                  0.950547     0.950547         0.950440  0.160917
# emp_length                   0.075514     0.075514         0.075552  0.054964
# annual_inc                   0.284569     0.284569         0.284568  0.060293
# loan_status                 -0.076721    -0.076721        -0.076728 -0.081272
# dti                         -0.007618    -0.007618        -0.007656  0.021630
# delinq_2yrs                 -0.014941    -0.014941        -0.014970 -0.008658
# inq_last_6mths              -0.023293    -0.023293        -0.023333 -0.003251
# open_acc                     0.168774     0.168774         0.168746  0.061920
# pub_rec                     -0.032526    -0.032526        -0.032570 -0.005471
# revol_bal                    0.298041     0.298041         0.298031  0.075464
# total_acc                    0.180871     0.180871         0.180838  0.081825
# out_prncp                    0.523529     0.523529         0.523588  0.298781
# out_prncp_inv                0.523528     0.523528         0.523590  0.298922
# total_pymnt                  0.650574     0.650574         0.650523  0.191298
# total_pymnt_inv              0.650568     0.650568         0.650524  0.191504
# total_rec_prncp              0.579594     0.579594         0.579531  0.128586
# total_rec_int                0.623165     0.623165         0.623214  0.417725
# total_rec_late_fee           0.069657     0.069657         0.069659  0.013739
# recoveries                   0.059971     0.059971         0.059975  0.046764
# collection_recovery_fee      0.057890     0.057890         0.057891  0.043166
# last_pymnt_amnt              0.415799     0.415799         0.415787  0.162879
# collections_12_mths_ex_med  -0.021686    -0.021686        -0.021698 -0.011592
# acc_now_delinq              -0.004276    -0.004276        -0.004279 -0.004503
# tot_coll_amt                 0.002338     0.002338         0.002339  0.003289
# tot_cur_bal                  0.287357     0.287357         0.287389  0.108237
# ...                               ...          ...              ...       ...
# delinq_amnt                 -0.000955    -0.000955        -0.000972  0.003129
# mo_sin_old_il_acct           0.111416     0.111416         0.111421  0.068914
# mo_sin_old_rev_tl_op         0.165292     0.165292         0.165301  0.055587
# mo_sin_rcnt_rev_tl_op        0.040547     0.040547         0.040569  0.018375
# mo_sin_rcnt_tl               0.028008     0.028008         0.028027 -0.000498
# mort_acc                     0.199781     0.199781         0.199823  0.095368
# mths_since_recent_bc         0.015907     0.015907         0.015937  0.014249
# mths_since_recent_inq       -0.000489    -0.000489        -0.000466 -0.020766
# num_accts_ever_120_pd       -0.046724    -0.046724        -0.046757 -0.013091
# num_actv_bc_tl               0.189820     0.189820         0.189778  0.048217
# num_actv_rev_tl              0.146459     0.146459         0.146425  0.047708
# num_bc_sats                  0.215603     0.215603         0.215569  0.054069
# num_bc_tl                    0.202748     0.202748         0.202704  0.048491
# num_il_tl                    0.070534     0.070534         0.070513  0.059906
# num_op_rev_tl                0.159870     0.159870         0.159840  0.048090
# num_rev_accts                0.158335     0.158335         0.158296  0.045476
# num_rev_tl_bal_gt_0          0.146670     0.146670         0.146637  0.047820
# num_sats                     0.169416     0.169416         0.169389  0.062036
# num_tl_120dpd_2m            -0.001391    -0.001391        -0.001407 -0.003002
# num_tl_30dpd                -0.002776    -0.002776        -0.002773 -0.001677
# num_tl_90g_dpd_24m          -0.023639    -0.023639        -0.023652 -0.008854
# num_tl_op_past_12m          -0.020709    -0.020709        -0.020720  0.006536
# pct_tl_nvr_dlq               0.076661     0.076661         0.076702  0.033330
# percent_bc_gt_75             0.012029     0.012029         0.012040  0.022854
# pub_rec_bankruptcies        -0.054320    -0.054320        -0.054367  0.001511
# tax_liens                    0.015152     0.015152         0.015142 -0.005983
# tot_hi_cred_lim              0.316839     0.316839         0.316868  0.107022
# total_bal_ex_mort            0.253257     0.253257         0.253251  0.095893
# total_bc_limit               0.355129     0.355129         0.355124  0.071464
# total_il_high_credit_limit   0.217327     0.217327         0.217316  0.086403
#
#                             int_rate  installment  emp_length  annual_inc  \
# loan_amnt                   0.106926     0.950547    0.075514    0.284569
# funded_amnt                 0.106926     0.950547    0.075514    0.284569
# funded_amnt_inv             0.107049     0.950440    0.075552    0.284568
# term                        0.354823     0.160917    0.054964    0.060293
# int_rate                    1.000000     0.157380   -0.014232   -0.062633
# installment                 0.157380     1.000000    0.063831    0.270291
# emp_length                 -0.014232     0.063831    1.000000    0.066119
# annual_inc                 -0.062633     0.270291    0.066119    1.000000
# loan_status                 0.037223    -0.049501    0.016885    0.000362
# dti                         0.185094     0.017485    0.047817   -0.172891
# delinq_2yrs                 0.069364    -0.004048    0.015748    0.026647
# inq_last_6mths              0.162731    -0.003009   -0.006028    0.021544
# open_acc                   -0.008917     0.161375    0.051250    0.124726
# pub_rec                     0.061187    -0.021803    0.027567   -0.001055
# revol_bal                   0.009495     0.293022    0.090174    0.283944
# total_acc                  -0.045291     0.161425    0.103538    0.157335
# out_prncp                   0.002771     0.446180    0.031037    0.131733
# out_prncp_inv               0.002827     0.446132    0.031050    0.131738
# total_pymnt                 0.147637     0.663695    0.059698    0.198720
# total_pymnt_inv             0.147731     0.663621    0.059729    0.198715
# total_rec_prncp             0.078849     0.596173    0.055880    0.187444
# total_rec_int               0.431769     0.607370    0.043323    0.132600
# total_rec_late_fee          0.062710     0.083416    0.001903    0.026646
# recoveries                  0.073942     0.062428   -0.002665    0.008062
# collection_recovery_fee     0.068881     0.060218   -0.001763    0.008272
# last_pymnt_amnt             0.121954     0.413548    0.052985    0.130701
# collections_12_mths_ex_med  0.024648    -0.015766   -0.010910   -0.010038
# acc_now_delinq              0.004183    -0.001984    0.003545    0.008039
# tot_coll_amt                0.006336     0.002186    0.002884   -0.001077
# tot_cur_bal                -0.079004     0.255400    0.109072    0.361789
# ...                              ...          ...         ...         ...
# delinq_amnt                 0.003493    -0.001208    0.003910    0.003674
# mo_sin_old_il_acct         -0.059601     0.088548    0.125200    0.110882
# mo_sin_old_rev_tl_op       -0.119135     0.141968    0.214799    0.151205
# mo_sin_rcnt_rev_tl_op      -0.078285     0.024800    0.018399    0.031397
# mo_sin_rcnt_tl             -0.099522     0.016768   -0.019669   -0.028797
# mort_acc                   -0.110087     0.163733    0.200525    0.200810
# mths_since_recent_bc       -0.064808     0.001636    0.038924    0.023343
# mths_since_recent_inq      -0.124135    -0.008707    0.006303   -0.040883
# num_accts_ever_120_pd       0.065508    -0.036908   -0.003402   -0.000773
# num_actv_bc_tl              0.064024     0.200620    0.087479    0.112635
# num_actv_rev_tl             0.108086     0.161285    0.128616    0.089019
# num_bc_sats                -0.040254     0.209763    0.075592    0.121432
# num_bc_tl                  -0.070921     0.193391    0.114928    0.133941
# num_il_tl                   0.004722     0.055707   -0.037714    0.089643
# num_op_rev_tl              -0.003505     0.158698    0.119747    0.084273
# num_rev_accts              -0.048586     0.150925    0.150376    0.102256
# num_rev_tl_bal_gt_0         0.108320     0.161475    0.128801    0.089253
# num_sats                   -0.009178     0.161972    0.050701    0.124780
# num_tl_120dpd_2m            0.001220    -0.000295    0.001946    0.005379
# num_tl_30dpd                0.005010    -0.001288    0.003326    0.006009
# num_tl_90g_dpd_24m          0.039272    -0.018117   -0.007729   -0.001246
# num_tl_op_past_12m          0.161753    -0.002636    0.027338    0.041798
# pct_tl_nvr_dlq             -0.091295     0.059620   -0.004398    0.007685
# percent_bc_gt_75            0.275667     0.045651    0.028388    0.014646
# pub_rec_bankruptcies        0.062420    -0.046835    0.025048   -0.032442
# tax_liens                   0.019401     0.021518    0.010359    0.036759
# tot_hi_cred_lim            -0.120980     0.280684    0.129138    0.380172
# total_bal_ex_mort           0.022160     0.240404   -0.007881    0.284055
# total_bc_limit             -0.218117     0.319877    0.075376    0.248058
# total_il_high_credit_limit -0.009050     0.200814   -0.014964    0.253611
#
#                             loan_status       dti             ...              \
# loan_amnt                     -0.076721 -0.007618             ...
# funded_amnt                   -0.076721 -0.007618             ...
# funded_amnt_inv               -0.076728 -0.007656             ...
# term                          -0.081272  0.021630             ...
# int_rate                       0.037223  0.185094             ...
# installment                   -0.049501  0.017485             ...
# emp_length                     0.016885  0.047817             ...
# annual_inc                     0.000362 -0.172891             ...
# loan_status                    1.000000 -0.055328             ...
# dti                           -0.055328  1.000000             ...
# delinq_2yrs                    0.001238 -0.033862             ...
# inq_last_6mths                 0.051473 -0.023737             ...
# open_acc                      -0.002111  0.252237             ...
# pub_rec                        0.035520 -0.047770             ...
# revol_bal                     -0.019975  0.156351             ...
# total_acc                      0.074220  0.204063             ...
# out_prncp                     -0.677591  0.025296             ...
# out_prncp_inv                 -0.677551  0.025270             ...
# total_pymnt                    0.534632 -0.021775             ...
# total_pymnt_inv                0.534650 -0.021797             ...
# total_rec_prncp                0.599770 -0.039205             ...
# total_rec_int                 -0.172387  0.089983             ...
# total_rec_late_fee            -0.029960 -0.003214             ...
# recoveries                    -0.072112  0.012541             ...
# collection_recovery_fee       -0.070045  0.012216             ...
# last_pymnt_amnt                0.641893 -0.028295             ...
# collections_12_mths_ex_med    -0.003808 -0.016875             ...
# acc_now_delinq                 0.008751 -0.002450             ...
# tot_coll_amt                   0.003109 -0.003015             ...
# tot_cur_bal                    0.047933 -0.008160             ...
# ...                                 ...       ...             ...
# delinq_amnt                    0.003169 -0.007082             ...
# mo_sin_old_il_acct             0.013318  0.082658             ...
# mo_sin_old_rev_tl_op           0.006953  0.061467             ...
# mo_sin_rcnt_rev_tl_op         -0.037222 -0.001195             ...
# mo_sin_rcnt_tl                -0.063961 -0.017684             ...
# mort_acc                       0.082175 -0.028745             ...
# mths_since_recent_bc          -0.027808  0.002832             ...
# mths_since_recent_inq         -0.063747  0.027796             ...
# num_accts_ever_120_pd          0.007478 -0.053413             ...
# num_actv_bc_tl                -0.061478  0.198582             ...
# num_actv_rev_tl               -0.061073  0.260624             ...
# num_bc_sats                   -0.015229  0.126751             ...
# num_bc_tl                      0.043739  0.097806             ...
# num_il_tl                      0.045135  0.180558             ...
# num_op_rev_tl                 -0.001901  0.184211             ...
# num_rev_accts                  0.051558  0.146936             ...
# num_rev_tl_bal_gt_0           -0.061010  0.260729             ...
# num_sats                      -0.002648  0.252391             ...
# num_tl_120dpd_2m               0.005428 -0.005068             ...
# num_tl_30dpd                   0.006521 -0.001185             ...
# num_tl_90g_dpd_24m             0.002584 -0.024534             ...
# num_tl_op_past_12m             0.080536  0.015462             ...
# pct_tl_nvr_dlq                 0.017386  0.111453             ...
# percent_bc_gt_75              -0.034582  0.146740             ...
# pub_rec_bankruptcies           0.038665 -0.027987             ...
# tax_liens                      0.000972 -0.038538             ...
# tot_hi_cred_lim                0.043455  0.011195             ...
# total_bal_ex_mort             -0.000095  0.250423             ...
# total_bc_limit                -0.008425  0.058756             ...
# total_il_high_credit_limit    -0.000945  0.291526             ...
#
#                             num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# loan_amnt                            -0.023639           -0.020709
# funded_amnt                          -0.023639           -0.020709
# funded_amnt_inv                      -0.023652           -0.020720
# term                                 -0.008854            0.006536
# int_rate                              0.039272            0.161753
# installment                          -0.018117           -0.002636
# emp_length                           -0.007729            0.027338
# annual_inc                           -0.001246            0.041798
# loan_status                           0.002584            0.080536
# dti                                  -0.024534            0.015462
# delinq_2yrs                           0.673950           -0.035347
# inq_last_6mths                        0.013021            0.327162
# open_acc                              0.003772            0.357553
# pub_rec                              -0.017834            0.057881
# revol_bal                            -0.033827           -0.012487
# total_acc                             0.050245            0.323844
# out_prncp                            -0.015088           -0.061113
# out_prncp_inv                        -0.015090           -0.061118
# total_pymnt                          -0.010376            0.030061
# total_pymnt_inv                      -0.010389            0.030058
# total_rec_prncp                      -0.011986            0.030428
# total_rec_int                         0.005297            0.006981
# total_rec_late_fee                    0.009571            0.003035
# recoveries                            0.001308            0.007352
# collection_recovery_fee               0.000810            0.006713
# last_pymnt_amnt                      -0.009967            0.051301
# collections_12_mths_ex_med            0.070564            0.002495
# acc_now_delinq                        0.041766           -0.006406
# tot_coll_amt                         -0.000249            0.001509
# tot_cur_bal                          -0.001217            0.103072
# ...                                        ...                 ...
# delinq_amnt                           0.035484           -0.005998
# mo_sin_old_il_acct                    0.044781            0.018755
# mo_sin_old_rev_tl_op                  0.017696           -0.012163
# mo_sin_rcnt_rev_tl_op                 0.012051           -0.397326
# mo_sin_rcnt_tl                        0.014463           -0.556411
# mort_acc                              0.001725            0.074745
# mths_since_recent_bc                  0.028041           -0.296090
# mths_since_recent_inq                -0.014355           -0.310150
# num_accts_ever_120_pd                 0.321260            0.070255
# num_actv_bc_tl                       -0.034877            0.179522
# num_actv_rev_tl                      -0.024945            0.247514
# num_bc_sats                          -0.039085            0.276438
# num_bc_tl                             0.000530            0.271214
# num_il_tl                             0.062965            0.149344
# num_op_rev_tl                        -0.027165            0.371020
# num_rev_accts                         0.011533            0.331123
# num_rev_tl_bal_gt_0                  -0.024907            0.247855
# num_sats                              0.003393            0.357028
# num_tl_120dpd_2m                      0.060043           -0.004923
# num_tl_30dpd                          0.000775           -0.004992
# num_tl_90g_dpd_24m                    1.000000           -0.012451
# num_tl_op_past_12m                   -0.012451            1.000000
# pct_tl_nvr_dlq                       -0.265663            0.033210
# percent_bc_gt_75                     -0.006136           -0.187414
# pub_rec_bankruptcies                 -0.030073            0.067592
# tax_liens                             0.000905            0.011780
# tot_hi_cred_lim                      -0.006314            0.109738
# total_bal_ex_mort                     0.014371            0.098493
# total_bc_limit                       -0.061094            0.094423
# total_il_high_credit_limit            0.024494            0.097737
#
#                             pct_tl_nvr_dlq  percent_bc_gt_75  \
# loan_amnt                         0.076661          0.012029
# funded_amnt                       0.076661          0.012029
# funded_amnt_inv                   0.076702          0.012040
# term                              0.033330          0.022854
# int_rate                         -0.091295          0.275667
# installment                       0.059620          0.045651
# emp_length                       -0.004398          0.028388
# annual_inc                        0.007685          0.014646
# loan_status                       0.017386         -0.034582
# dti                               0.111453          0.146740
# delinq_2yrs                      -0.426043          0.011009
# inq_last_6mths                   -0.005934         -0.113096
# open_acc                          0.117785         -0.083187
# pub_rec                           0.042597         -0.009188
# revol_bal                         0.108398          0.166883
# total_acc                         0.049141         -0.061822
# out_prncp                         0.032017          0.010080
# out_prncp_inv                     0.032034          0.010083
# total_pymnt                       0.050871          0.021136
# total_pymnt_inv                   0.050903          0.021145
# total_rec_prncp                   0.055150         -0.004597
# total_rec_int                    -0.005964          0.151134
# total_rec_late_fee               -0.026179          0.025751
# recoveries                       -0.003263          0.019555
# collection_recovery_fee          -0.003166          0.020277
# last_pymnt_amnt                   0.048072         -0.006511
# collections_12_mths_ex_med       -0.049534         -0.029665
# acc_now_delinq                   -0.034603         -0.013480
# tot_coll_amt                     -0.007546         -0.003499
# tot_cur_bal                       0.022690          0.058660
# ...                                    ...               ...
# delinq_amnt                      -0.007920         -0.002631
# mo_sin_old_il_acct               -0.110396          0.062355
# mo_sin_old_rev_tl_op             -0.060469          0.038013
# mo_sin_rcnt_rev_tl_op            -0.035471          0.136053
# mo_sin_rcnt_tl                   -0.038916          0.159945
# mort_acc                         -0.002259          0.021540
# mths_since_recent_bc             -0.055898          0.166717
# mths_since_recent_inq             0.013548          0.115654
# num_accts_ever_120_pd            -0.625253          0.006947
# num_actv_bc_tl                    0.114563          0.042407
# num_actv_rev_tl                   0.096257          0.105118
# num_bc_sats                       0.161488         -0.181770
# num_bc_tl                         0.090795         -0.162233
# num_il_tl                         0.001323          0.023621
# num_op_rev_tl                     0.146082         -0.131179
# num_rev_accts                     0.078562         -0.119987
# num_rev_tl_bal_gt_0               0.096377          0.104899
# num_sats                          0.117905         -0.083052
# num_tl_120dpd_2m                 -0.015761         -0.004190
# num_tl_30dpd                     -0.027774         -0.012121
# num_tl_90g_dpd_24m               -0.265663         -0.006136
# num_tl_op_past_12m                0.033210         -0.187414
# pct_tl_nvr_dlq                    1.000000         -0.050515
# percent_bc_gt_75                 -0.050515          1.000000
# pub_rec_bankruptcies              0.108012         -0.014640
# tax_liens                        -0.024918         -0.000727
# tot_hi_cred_lim                   0.042489          0.011276
# total_bal_ex_mort                 0.059329          0.080245
# total_bc_limit                    0.222557         -0.213482
# total_il_high_credit_limit        0.035714          0.026677
#
#                             pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# loan_amnt                              -0.054320   0.015152         0.316839
# funded_amnt                            -0.054320   0.015152         0.316839
# funded_amnt_inv                        -0.054367   0.015142         0.316868
# term                                    0.001511  -0.005983         0.107022
# int_rate                                0.062420   0.019401        -0.120980
# installment                            -0.046835   0.021518         0.280684
# emp_length                              0.025048   0.010359         0.129138
# annual_inc                             -0.032442   0.036759         0.380172
# loan_status                             0.038665   0.000972         0.043455
# dti                                    -0.027987  -0.038538         0.011195
# delinq_2yrs                            -0.062798   0.006650         0.040478
# inq_last_6mths                          0.069191   0.019786         0.013958
# open_acc                               -0.013041  -0.013146         0.290038
# pub_rec                                 0.688377   0.684613        -0.066419
# revol_bal                              -0.094075  -0.001770         0.456573
# total_acc                              -0.002469  -0.025546         0.351536
# out_prncp                              -0.048099  -0.001896         0.116363
# out_prncp_inv                          -0.048117  -0.001896         0.116383
# total_pymnt                            -0.016845   0.022346         0.250019
# total_pymnt_inv                        -0.016880   0.022336         0.250038
# total_rec_prncp                        -0.016416   0.016372         0.242301
# total_rec_int                          -0.008918   0.041403         0.131426
# total_rec_late_fee                     -0.009293   0.027534         0.021552
# recoveries                              0.003147   0.002823         0.001627
# collection_recovery_fee                 0.003442   0.001968         0.002234
# last_pymnt_amnt                         0.000680   0.003013         0.186328
# collections_12_mths_ex_med             -0.011154   0.009489        -0.018715
# acc_now_delinq                         -0.010644   0.001608         0.021402
# tot_coll_amt                            0.000906   0.001925        -0.004620
# tot_cur_bal                            -0.079671   0.001555         0.973504
# ...                                          ...        ...              ...
# delinq_amnt                            -0.002012   0.003747         0.016694
# mo_sin_old_il_acct                      0.019358   0.012171         0.203576
# mo_sin_old_rev_tl_op                    0.031581   0.012094         0.251115
# mo_sin_rcnt_rev_tl_op                  -0.066083  -0.006010         0.035132
# mo_sin_rcnt_tl                         -0.045987  -0.011585        -0.080386
# mort_acc                               -0.042829  -0.014373         0.574384
# mths_since_recent_bc                   -0.055122  -0.002647         0.041027
# mths_since_recent_inq                  -0.057724  -0.017803        -0.063748
# num_accts_ever_120_pd                  -0.062057   0.005227        -0.015022
# num_actv_bc_tl                         -0.051319   0.012081         0.151105
# num_actv_rev_tl                         0.002650   0.009671         0.142760
# num_bc_sats                            -0.067770   0.001051         0.190071
# num_bc_tl                              -0.026443  -0.009420         0.219327
# num_il_tl                              -0.024711  -0.018600         0.205651
# num_op_rev_tl                           0.024008  -0.005315         0.165243
# num_rev_accts                           0.031590  -0.019065         0.205199
# num_rev_tl_bal_gt_0                     0.002765   0.009555         0.143158
# num_sats                               -0.018244  -0.013220         0.290269
# num_tl_120dpd_2m                       -0.003940  -0.000960         0.013171
# num_tl_30dpd                           -0.011385   0.001324         0.015994
# num_tl_90g_dpd_24m                     -0.030073   0.000905        -0.006314
# num_tl_op_past_12m                      0.067592   0.011780         0.109738
# pct_tl_nvr_dlq                          0.108012  -0.024918         0.042489
# percent_bc_gt_75                       -0.014640  -0.000727         0.011276
# pub_rec_bankruptcies                    1.000000   0.035052        -0.092343
# tax_liens                               0.035052   1.000000         0.001276
# tot_hi_cred_lim                        -0.092343   0.001276         1.000000
# total_bal_ex_mort                      -0.068523  -0.001216         0.510194
# total_bc_limit                         -0.135647  -0.022697         0.408781
# total_il_high_credit_limit             -0.045488   0.001701         0.447647
#
#                             total_bal_ex_mort  total_bc_limit  \
# loan_amnt                            0.253257        0.355129
# funded_amnt                          0.253257        0.355129
# funded_amnt_inv                      0.253251        0.355124
# term                                 0.095893        0.071464
# int_rate                             0.022160       -0.218117
# installment                          0.240404        0.319877
# emp_length                          -0.007881        0.075376
# annual_inc                           0.284055        0.248058
# loan_status                         -0.000095       -0.008425
# dti                                  0.250423        0.058756
# delinq_2yrs                          0.019487       -0.086231
# inq_last_6mths                       0.027853        0.026660
# open_acc                             0.382513        0.418197
# pub_rec                             -0.052601       -0.118138
# revol_bal                            0.515289        0.451033
# total_acc                            0.443174        0.341518
# out_prncp                            0.116601        0.177107
# out_prncp_inv                        0.116595        0.177104
# total_pymnt                          0.183135        0.230267
# total_pymnt_inv                      0.183134        0.230265
# total_rec_prncp                      0.166120        0.226699
# total_rec_int                        0.159629        0.101687
# total_rec_late_fee                   0.023015       -0.011471
# recoveries                           0.010462       -0.002581
# collection_recovery_fee              0.010562       -0.002211
# last_pymnt_amnt                      0.123264        0.153465
# collections_12_mths_ex_med          -0.016813       -0.035163
# acc_now_delinq                       0.004484        0.007840
# tot_coll_amt                        -0.003186       -0.004665
# tot_cur_bal                          0.529474        0.304568
# ...                                       ...             ...
# delinq_amnt                          0.001541       -0.003176
# mo_sin_old_il_acct                   0.242956        0.093185
# mo_sin_old_rev_tl_op                 0.141196        0.267981
# mo_sin_rcnt_rev_tl_op                0.024732       -0.055021
# mo_sin_rcnt_tl                      -0.064017       -0.051984
# mort_acc                             0.170330        0.225861
# mths_since_recent_bc                 0.024952       -0.127461
# mths_since_recent_inq               -0.051601       -0.010978
# num_accts_ever_120_pd                0.022941       -0.133385
# num_actv_bc_tl                       0.163206        0.482975
# num_actv_rev_tl                      0.163690        0.319656
# num_bc_sats                          0.153188        0.657844
# num_bc_tl                            0.152499        0.576815
# num_il_tl                            0.508285        0.044802
# num_op_rev_tl                        0.140216        0.463211
# num_rev_accts                        0.145430        0.420813
# num_rev_tl_bal_gt_0                  0.164256        0.319925
# num_sats                             0.382759        0.419365
# num_tl_120dpd_2m                     0.003436       -0.000204
# num_tl_30dpd                         0.000826        0.006874
# num_tl_90g_dpd_24m                   0.014371       -0.061094
# num_tl_op_past_12m                   0.098493        0.094423
# pct_tl_nvr_dlq                       0.059329        0.222557
# percent_bc_gt_75                     0.080245       -0.213482
# pub_rec_bankruptcies                -0.068523       -0.135647
# tax_liens                           -0.001216       -0.022697
# tot_hi_cred_lim                      0.510194        0.408781
# total_bal_ex_mort                    1.000000        0.279799
# total_bc_limit                       0.279799        1.000000
# total_il_high_credit_limit           0.897658        0.180613
#
#                             total_il_high_credit_limit
# loan_amnt                                     0.217327
# funded_amnt                                   0.217327
# funded_amnt_inv                               0.217316
# term                                          0.086403
# int_rate                                     -0.009050
# installment                                   0.200814
# emp_length                                   -0.014964
# annual_inc                                    0.253611
# loan_status                                  -0.000945
# dti                                           0.291526
# delinq_2yrs                                   0.041725
# inq_last_6mths                                0.033891
# open_acc                                      0.348130
# pub_rec                                      -0.034561
# revol_bal                                     0.191618
# total_acc                                     0.434992
# out_prncp                                     0.103416
# out_prncp_inv                                 0.103413
# total_pymnt                                   0.152817
# total_pymnt_inv                               0.152807
# total_rec_prncp                               0.139578
# total_rec_int                                 0.127641
# total_rec_late_fee                            0.021016
# recoveries                                    0.008970
# collection_recovery_fee                       0.008795
# last_pymnt_amnt                               0.104272
# collections_12_mths_ex_med                   -0.007970
# acc_now_delinq                                0.008477
# tot_coll_amt                                 -0.002493
# tot_cur_bal                                   0.453149
# ...                                                ...
# delinq_amnt                                   0.001812
# mo_sin_old_il_acct                            0.259297
# mo_sin_old_rev_tl_op                          0.096609
# mo_sin_rcnt_rev_tl_op                         0.033568
# mo_sin_rcnt_tl                               -0.067823
# mort_acc                                      0.148488
# mths_since_recent_bc                          0.030690
# mths_since_recent_inq                        -0.060652
# num_accts_ever_120_pd                         0.034870
# num_actv_bc_tl                                0.067805
# num_actv_rev_tl                               0.061481
# num_bc_sats                                   0.083918
# num_bc_tl                                     0.096958
# num_il_tl                                     0.555994
# num_op_rev_tl                                 0.072543
# num_rev_accts                                 0.093834
# num_rev_tl_bal_gt_0                           0.061638
# num_sats                                      0.348184
# num_tl_120dpd_2m                              0.004429
# num_tl_30dpd                                  0.003924
# num_tl_90g_dpd_24m                            0.024494
# num_tl_op_past_12m                            0.097737
# pct_tl_nvr_dlq                                0.035714
# percent_bc_gt_75                              0.026677
# pub_rec_bankruptcies                         -0.045488
# tax_liens                                     0.001701
# tot_hi_cred_lim                               0.447647
# total_bal_ex_mort                             0.897658
# total_bc_limit                                0.180613
# total_il_high_credit_limit                    1.000000
#
# [80 rows x 80 columns]

# %% [markdown]
# #### Sorting and displaying the correlation values with respect to loan_status

# %%
loan_st_corr = y.iloc[8]
loan_st_corr = loan_st_corr.to_frame().reset_index()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
loan_st_corr.sort_values(by ='loan_status', ascending = False)
# Out:
#                          index  loan_status
# 8                  loan_status     1.000000
# 25             last_pymnt_amnt     0.641893
# 20             total_rec_prncp     0.599770
# 19             total_pymnt_inv     0.534650
# 18                 total_pymnt     0.534632
# 33                 open_il_24m     0.094473
# 45        acc_open_past_24mths     0.089173
# 55                    mort_acc     0.082175
# 32                 open_il_12m     0.081099
# 71          num_tl_op_past_12m     0.080536
# 15                   total_acc     0.074220
# 44                inq_last_12m     0.067680
# 43                 total_cu_tl     0.060201
# 30                 open_acc_6m     0.057036
# 36                     il_util     0.054993
# 46                 avg_cur_bal     0.053956
# 65               num_rev_accts     0.051558
# 11              inq_last_6mths     0.051473
# 29                 tot_cur_bal     0.047933
# 42                      inq_fi     0.047340
# 63                   num_il_tl     0.045135
# 62                   num_bc_tl     0.043739
# 76             tot_hi_cred_lim     0.043455
# 74        pub_rec_bankruptcies     0.038665
# 38                 open_rv_24m     0.038015
# 4                     int_rate     0.037223
# 37                 open_rv_12m     0.037156
# 13                     pub_rec     0.035520
# 47              bc_open_to_buy     0.018457
# 72              pct_tl_nvr_dlq     0.017386
# 6                   emp_length     0.016885
# 51          mo_sin_old_il_acct     0.013318
# 35                total_bal_il     0.010442
# 27              acc_now_delinq     0.008751
# 58       num_accts_ever_120_pd     0.007478
# 52        mo_sin_old_rev_tl_op     0.006953
# 69                num_tl_30dpd     0.006521
# 68            num_tl_120dpd_2m     0.005428
# 49    chargeoff_within_12_mths     0.003642
# 50                 delinq_amnt     0.003169
# 28                tot_coll_amt     0.003109
# 70          num_tl_90g_dpd_24m     0.002584
# 41            total_rev_hi_lim     0.001829
# 10                 delinq_2yrs     0.001238
# 75                   tax_liens     0.000972
# 7                   annual_inc     0.000362
# 77           total_bal_ex_mort    -0.000095
# 79  total_il_high_credit_limit    -0.000945
# 64               num_op_rev_tl    -0.001901
# 12                    open_acc    -0.002111
# 67                    num_sats    -0.002648
# 26  collections_12_mths_ex_med    -0.003808
# 78              total_bc_limit    -0.008425
# 31                 open_act_il    -0.012579
# 40                    all_util    -0.012737
# 61                 num_bc_sats    -0.015229
# 14                   revol_bal    -0.019975
# 39                  max_bal_bc    -0.027694
# 56        mths_since_recent_bc    -0.027808
# 22          total_rec_late_fee    -0.029960
# 73            percent_bc_gt_75    -0.034582
# 53       mo_sin_rcnt_rev_tl_op    -0.037222
# 5                  installment    -0.049501
# 9                          dti    -0.055328
# 48                     bc_util    -0.060008
# 66         num_rev_tl_bal_gt_0    -0.061010
# 60             num_actv_rev_tl    -0.061073
# 59              num_actv_bc_tl    -0.061478
# 57       mths_since_recent_inq    -0.063747
# 54              mo_sin_rcnt_tl    -0.063961
# 34          mths_since_rcnt_il    -0.068778
# 24     collection_recovery_fee    -0.070045
# 23                  recoveries    -0.072112
# 1                  funded_amnt    -0.076721
# 0                    loan_amnt    -0.076721
# 2              funded_amnt_inv    -0.076728
# 3                         term    -0.081272
# 21               total_rec_int    -0.172387
# 17               out_prncp_inv    -0.677551
# 16                   out_prncp    -0.677591

# %% [markdown]
# #### Selecting columns of type 'string' as stringColumnList

# %%
stringColumnList = [item[0] for item in df.dtypes if item[1].startswith('string') or item[0]=='loan_status']

# %% [markdown]
# #### String Indexing the categorical variables and applying OneHotEncoding to convert string categorical features to numerics

# %%
categorical_columns = stringColumnList
string_indexer_models = []
one_hot_encoders = []
for col_name in categorical_columns:
    # OneHotEncoders map number indices column to column of binary vectors
    string_indexer_model = feature.StringIndexer(inputCol=col_name, outputCol="{0}_indexed".format(col_name)).fit(df)
    df = string_indexer_model.transform(df)
    string_indexer_models.append(string_indexer_model)
    
    one_hot_encoder = feature.OneHotEncoder(inputCol="{0}_indexed".format(col_name), outputCol="{0}_encoded".format(col_name), dropLast=False)
    df = one_hot_encoder.transform(df)
    one_hot_encoders.append(one_hot_encoder)

# %% [markdown]
# #### Creating Train, Validation and Test Splits

# %%
training_df, validation_df, testing_df = df.randomSplit([0.6, 0.3, 0.1], seed=0)#create 3 sets of data for cross-validation

# %%
[training_df.count(), validation_df.count(), testing_df.count()]
# Out:
# [92575, 46167, 15668]

# %% [markdown]
# #### Considering highly correlated features with a correlation values > 0.1
# #### Also considered few features based on intuition which would best explain the loan_status
#
# ##### We also have eliminated certain features that had similar correlation with the output label

# %%
va = feature.VectorAssembler(inputCols=['loan_amnt',
 'term',
 'mort_acc',
 'funded_amnt_inv',
 'int_rate',
 'installment',
 'total_rec_int',
 'tot_hi_cred_lim',
 'sub_grade_encoded',
 'home_ownership_encoded',
 'verification_status_encoded',
 'purpose_encoded',
 'revol_util_encoded'] 
 ,outputCol='features')

# %% [markdown]
# #### Logistic regression implemntation based on correlation values & intutive feature selection

# %%
lr = LogisticRegression().setFeaturesCol('features').setLabelCol('loan_status')
pipe = Pipeline(stages=[va, lr])
pipe_model = pipe.fit(training_df)
evaluator = evaluation.BinaryClassificationEvaluator(labelCol='loan_status')
evaluator.evaluate(pipe_model.transform(validation_df))#Model 8 as per poster
# Out:
# 0.6589241606323537

# %% [markdown]
# #### Random Forest Classifier implementation based on correlation values and intuitive feature selection

# %%
rf = RandomForestClassifier().setFeaturesCol('features').setLabelCol('loan_status')
rf_pipeline = Pipeline(stages=[va, rf]).fit(training_df)
evaluator = evaluation.BinaryClassificationEvaluator(labelCol='loan_status')
evaluator.evaluate(rf_pipeline.transform(validation_df))#model 7 as per poster
# Out:
# 0.612630073888343
